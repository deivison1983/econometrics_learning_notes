# %% [markdown]
# # 0.0 Imports

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import gridspec
from IPython.display import Image
from IPython.core.display import HTML

import scipy
from scipy import stats

import sklearn
from sklearn.linear_model import LinearRegression

import seaborn as seabornInstance 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
import statsmodels.api as sm

# %% [markdown]
# # 0.1 Funções de auxílio

# %%
#ajusta graficos
def jupyter_settings():
    # %matplotlib inline
    # %pylab inline
    
    plt.style.use( 'bmh' )
    plt.rcParams['figure.figsize'] = [25, 12]
    plt.rcParams['font.size'] = 24
    
    display( HTML( '<style>.container { width:100% !important; }</style>') )
    pd.options.display.max_columns = None
    pd.options.display.max_rows = None
    pd.set_option( 'display.expand_frame_repr', False )
    
    sns.set()

jupyter_settings()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <style>.container { width:100% !important; }</style>

# %%
plt.rc('xtick',labelsize=15)
plt.rc('ytick',labelsize=15)
plt.rc('axes' ,labelsize=18)

# %% [markdown]
# # Capítulo 3 - Modelo de regressão de duas variáveis: o problema da estimação

# %%
Image( '/home/deivison/Documentos/projetos/econometria/imagens/cap_03_intro.png')

# %% [markdown]
# ## 3.1 Método dos Mínimos Quadrados Ordinários

# %%
Image( '/home/deivison/Documentos/projetos/econometria/imagens/mqo_1.png')

# %%
Image( '/home/deivison/Documentos/projetos/econometria/imagens/mqo_2.png')

# %% [markdown]
# ### PROPRIEDADES DO MQO

# %%
Image( '/home/deivison/Documentos/projetos/econometria/imagens/mqo_3.png')

# %%
Image( '/home/deivison/Documentos/projetos/econometria/imagens/mqo_4.png')

# %%
Image( '/home/deivison/Documentos/projetos/econometria/imagens/mqo_5.png')

# %% [markdown]
# ### PROPRIEDADES DA LINHA DE REGRESSÃO

# %%
Image( '/home/deivison/Documentos/projetos/econometria/imagens/mqo_6.png')

# %%
Image( '/home/deivison/Documentos/projetos/econometria/imagens/mqo_7.png')

# %%
Image( '/home/deivison/Documentos/projetos/econometria/imagens/mqo_8.png')

# %%
Image( '/home/deivison/Documentos/projetos/econometria/imagens/mqo_9.png')

# %%
Image( '/home/deivison/Documentos/projetos/econometria/imagens/mqo_10.png')

# %%
Image( '/home/deivison/Documentos/projetos/econometria/imagens/mqo_11.png')

# %% [markdown]
# ## 3.2 Modelo Clássico de Regressão Linear: Hipóteses Subjacentes ao MQO

# %%
Image( '/home/deivison/Documentos/projetos/econometria/imagens/classico_1.png')

# %%
Image( '/home/deivison/Documentos/projetos/econometria/imagens/classico_2.png')

# %%
Image( '/home/deivison/Documentos/projetos/econometria/imagens/classico_4.png')

# %%
Image( '/home/deivison/Documentos/projetos/econometria/imagens/classico_3.png')

# %%
Image( '/home/deivison/Documentos/projetos/econometria/imagens/classico_5.png')

# %%
Image( '/home/deivison/Documentos/projetos/econometria/imagens/classico_6.png')

# %%
Image( '/home/deivison/Documentos/projetos/econometria/imagens/classico_7.png')

# %%
Image( '/home/deivison/Documentos/projetos/econometria/imagens/classico_8.png')

# %%
Image( '/home/deivison/Documentos/projetos/econometria/imagens/classico_9.png')

# %%
Image( '/home/deivison/Documentos/projetos/econometria/imagens/classico_10.png')

# %%
Image( '/home/deivison/Documentos/projetos/econometria/imagens/classico_11.png')

# %%
Image( '/home/deivison/Documentos/projetos/econometria/imagens/classico_12.png')

# %%
Image( '/home/deivison/Documentos/projetos/econometria/imagens/classico_13.png')

# %%
Image( '/home/deivison/Documentos/projetos/econometria/imagens/classico_14.png')

# %% [markdown]
# ## 3.4 Propriedades de Gauss-Markov

# %%
Image( '/home/deivison/Documentos/projetos/econometria/imagens/gauss_1.png')

# %%
Image( '/home/deivison/Documentos/projetos/econometria/imagens/gauss_2.png')

# %%
Image( '/home/deivison/Documentos/projetos/econometria/imagens/gauss_3.png')

# %% [markdown]
# ## 3.5 O Coeficiente de determinação $ { r² } $ : "qualidade do ajustamento"

# %%
Image( '/home/deivison/Documentos/projetos/econometria/imagens/r2_1.png')

# %%
Image( '/home/deivison/Documentos/projetos/econometria/imagens/r2_2.png')

# %%
Image( '/home/deivison/Documentos/projetos/econometria/imagens/r2_3.png')

# %%
Image( '/home/deivison/Documentos/projetos/econometria/imagens/r2_4.png')

# %% [markdown]
# ### COEFICIENTE DE CORRELAÇÃO

# %%
Image( '/home/deivison/Documentos/projetos/econometria/imagens/correlacao_1.png')

# %%
Image( '/home/deivison/Documentos/projetos/econometria/imagens/correlacao_2.png')

# %%
Image( '/home/deivison/Documentos/projetos/econometria/imagens/correlacao_3.png')

# %%
Image( '/home/deivison/Documentos/projetos/econometria/imagens/correlacao_4.png')

# %%
Image( '/home/deivison/Documentos/projetos/econometria/imagens/correlacao_5.png')

# %% [markdown]
# ## Resumo

# %%
Image( '/home/deivison/Documentos/projetos/econometria/imagens/cap_03_resumo.png')
